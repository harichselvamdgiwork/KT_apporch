# %%
# !git clone https://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@github.com/harichselvamdgiwork/okoklast data2
# Out:
# Cloning into 'data2'...
# remote: Enumerating objects: 93649, done.
# remote: Total 93649 (delta 0), reused 0 (delta 0), pack-reused 93649
# Receiving objects: 100% (93649/93649), 3.80 GiB | 36.32 MiB/s, done.
# Resolving deltas: 100% (4/4), done.
# Updating files: 100% (93522/93522), done.

# %%
# !mkdir csvfiles2

# %%
# !pip install ocr-tamil -q
# Out:
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# spopt 0.6.0 requires shapely>=2.0.1, but you have shapely 1.8.5.post1 which is incompatible.
# ydata-profiling 4.6.4 requires numpy<1.26,>=1.16.0, but you have numpy 1.26.4 which is incompatible.

# %%
import os
import re
import csv
from ocr_tamil.ocr import OCR

# Initialize the OCR object
ocr = OCR(detect=True)

# Function to process images and save results in each subfolder
def process_and_save_results(root_folder, output_folder):
    # Iterate over all subfolders in the root folder
    for folder_name in os.listdir(root_folder):
        folder_path = os.path.join(root_folder, folder_name)
        if os.path.isdir(folder_path):
            # Get a list of image files in the subfolder
            image_files = [f for f in os.listdir(folder_path) if f.endswith('.png') or f.endswith('.jpg')]
            total_images = len(image_files)
            print(f"Total number of images in '{folder_name}': {total_images}")

            # Create a CSV file to store the results in the subfolder
            csv_file_path = os.path.join(output_folder, f"{folder_name}.csv")
            with open(csv_file_path, mode='w', newline='', encoding='utf-8') as file:
                writer = csv.writer(file)
                writer.writerow(["Filename", "Age", "Gender"])

                # Iterate over all the files in the subfolder
                for i, filename in enumerate(image_files, start=1):
#                     print(f"Processing image {i}/{total_images}: {filename}")
                    # Construct the full path to the image file
                    image_path = os.path.join(folder_path, filename)

                    # Predict text from the image
                    texts = ocr.predict(image_path)

                    # Join the predicted text
                    text = ' '.join(texts[0])

                    # Extract ages above 18 from the text
                    age_pattern = r'(?:வயது\D*(\d{2})|(\d{2})\D*பாலினம்)'
                    age_matches = re.findall(age_pattern, text)
                    ages_above_18 = [age for match in age_matches for age in match if age and int(age) >= 18]

                    # Extract gender information from the text
                    gender_pattern = r'பாலினம்\D*:\D*(பெண்|ஆண்|மூன்றாம் பாலினம்)'
                    gender_matches = re.findall(gender_pattern, text)
                    gender = gender_matches[0] if gender_matches else None

                    # If "மூன்றாம் பாலினம்" is found, set gender accordingly
                    if "மூன்றாம் பாலினம்" in text:
                        gender = "மூன்றாம் பாலினம்"

                    # Convert gender to English
                    if gender == "பெண்":
                        gender = "female"
                    elif gender == "ஆண்":
                        gender = "male"
                    elif gender == "மூன்றாம் பாலினம்":
                        gender = "transgender"

                    # Write the results to the CSV file
                    writer.writerow([filename, ', '.join(ages_above_18), gender])
                    
                # Close the CSV file
                print(f"CSV file saved for '{folder_name}'.")

# Root folder containing subfolders with images
root_folder = "/kaggle/working/data2"

# Output folder for CSV files
output_folder = "/kaggle/working/csvfiles2"

# Process images and save results in each subfolder
process_and_save_results(root_folder, output_folder)
# Out:
# saving to /root/.model_weights/parseq_tamil_v3.pt
# Download would take several minutes
# 100%|██████████| 95.5M/95.5M [00:01<00:00, 50.4MB/s]
# saving to /root/.model_weights/craft_mlt_25k.pth
# Download would take several minutes
# 100%|██████████| 83.2M/83.2M [00:01<00:00, 51.9MB/s]
# Downloading: "https://github.com/gnana70/tamil_ocr/raw/develop/ocr_tamil/model_weights/parseq.pt" to /root/.cache/torch/hub/checkpoints/parseq.pt
# 100%|██████████| 91.0M/91.0M [00:00<00:00, 227MB/s]
# Total number of images in 'ac223254': 671
# CSV file saved for 'ac223254'.
# Total number of images in 'ac223314': 353
# CSV file saved for 'ac223314'.
# Total number of images in 'ac223301': 1365
# CSV file saved for 'ac223301'.
# Total number of images in 'ac223214': 885
# CSV file saved for 'ac223214'.
# Total number of images in 'ac223316': 811
# CSV file saved for 'ac223316'.
# Total number of images in 'ac223282': 773
# CSV file saved for 'ac223282'.
# Total number of images in 'ac223244': 739
# CSV file saved for 'ac223244'.
# Total number of images in 'ac223283': 1036
# CSV file saved for 'ac223283'.
# Total number of images in 'ac223275': 933
# CSV file saved for 'ac223275'.
# Total number of images in 'ac223217': 776
# CSV file saved for 'ac223217'.
# Total number of images in 'ac223279': 1071
# CSV file saved for 'ac223279'.
# Total number of images in 'ac223207': 856
# CSV file saved for 'ac223207'.
# Total number of images in 'ac223297': 760
# CSV file saved for 'ac223297'.
# Total number of images in 'ac223255': 1040
# CSV file saved for 'ac223255'.
# Total number of images in 'ac223238': 925
# CSV file saved for 'ac223238'.
# Total number of images in 'ac223232': 282
# CSV file saved for 'ac223232'.
# Total number of images in 'ac223269': 829
# CSV file saved for 'ac223269'.
# Total number of images in 'ac223257': 902
# CSV file saved for 'ac223257'.
# Total number of images in 'ac223295': 840
# CSV file saved for 'ac223295'.
# Total number of images in 'ac223307': 714
# CSV file saved for 'ac223307'.
# Total number of images in 'ac223212': 929
# CSV file saved for 'ac223212'.
# Total number of images in 'ac223319': 734
# CSV file saved for 'ac223319'.
# Total number of images in 'ac223205': 1103
# CSV file saved for 'ac223205'.
# Total number of images in 'ac223208': 855
# CSV file saved for 'ac223208'.
# Total number of images in 'ac223261': 697
# CSV file saved for 'ac223261'.
# Total number of images in 'ac223278': 304
# CSV file saved for 'ac223278'.
# Total number of images in 'ac223305': 897
# CSV file saved for 'ac223305'.
# Total number of images in 'ac223274': 973
# CSV file saved for 'ac223274'.
# Total number of images in 'ac223239': 957
# CSV file saved for 'ac223239'.
# Total number of images in 'ac223251': 479
# CSV file saved for 'ac223251'.
# Total number of images in 'ac223210': 931
# CSV file saved for 'ac223210'.
# Total number of images in 'ac223222': 842
# CSV file saved for 'ac223222'.
# Total number of images in 'ac223247': 660
# CSV file saved for 'ac223247'.
# Total number of images in 'ac223277': 578
# CSV file saved for 'ac223277'.
# Total number of images in 'ac223229': 1103
# CSV file saved for 'ac223229'.
# Total number of images in 'ac223233': 696
# CSV file saved for 'ac223233'.
# Total number of images in 'ac223250': 825
# CSV file saved for 'ac223250'.
# Total number of images in 'ac223242': 784
# CSV file saved for 'ac223242'.
# Total number of images in 'ac223286': 1001
# CSV file saved for 'ac223286'.
# Total number of images in 'ac223243': 664
# CSV file saved for 'ac223243'.
# Total number of images in 'ac223280': 646
# CSV file saved for 'ac223280'.
# Total number of images in 'ac223318': 1132
# CSV file saved for 'ac223318'.
# Total number of images in 'ac223292': 1107
# CSV file saved for 'ac223292'.
# Total number of images in 'ac223256': 558
# CSV file saved for 'ac223256'.
# Total number of images in 'ac223263': 1097
# CSV file saved for 'ac223263'.
# Total number of images in 'ac223223': 595
# CSV file saved for 'ac223223'.
# Total number of images in 'ac223290': 741
# CSV file saved for 'ac223290'.
# Total number of images in 'ac223312': 915
# CSV file saved for 'ac223312'.
# Total number of images in 'ac223262': 716
# CSV file saved for 'ac223262'.
# Total number of images in 'ac223253': 471
# CSV file saved for 'ac223253'.
# Total number of images in 'ac223273': 758
# CSV file saved for 'ac223273'.
# Total number of images in 'ac223260': 620
# CSV file saved for 'ac223260'.
# Total number of images in 'ac223284': 1007
# CSV file saved for 'ac223284'.
# Total number of images in 'ac223285': 825
# CSV file saved for 'ac223285'.
# Total number of images in 'ac223209': 643
# CSV file saved for 'ac223209'.
# Total number of images in 'ac223228': 881
# CSV file saved for 'ac223228'.
# Total number of images in 'ac223288': 929
# CSV file saved for 'ac223288'.
# Total number of images in 'ac223310': 1389
# CSV file saved for 'ac223310'.
# Total number of images in 'ac223224': 494
# CSV file saved for 'ac223224'.
# Total number of images in 'ac223216': 578
# CSV file saved for 'ac223216'.
# Total number of images in 'ac223272': 930
# CSV file saved for 'ac223272'.
# Total number of images in 'ac223258': 1063
# CSV file saved for 'ac223258'.
# Total number of images in 'ac223303': 851
# CSV file saved for 'ac223303'.
# Total number of images in 'ac223226': 776
# CSV file saved for 'ac223226'.
# Total number of images in 'ac223289': 685
# CSV file saved for 'ac223289'.
# Total number of images in 'ac223234': 764
# CSV file saved for 'ac223234'.
# Total number of images in 'ac223204': 1030
# CSV file saved for 'ac223204'.
# Total number of images in 'ac223235': 704
# CSV file saved for 'ac223235'.
# Total number of images in 'ac223213': 1172
# CSV file saved for 'ac223213'.
# Total number of images in 'ac223220': 850
# CSV file saved for 'ac223220'.
# Total number of images in 'ac223203': 565
# CSV file saved for 'ac223203'.
# Total number of images in 'ac223241': 917
# CSV file saved for 'ac223241'.
# Total number of images in 'ac223270': 711
# CSV file saved for 'ac223270'.
# Total number of images in 'ac223267': 726
# CSV file saved for 'ac223267'.
# Total number of images in 'ac223317': 742
# CSV file saved for 'ac223317'.
# Total number of images in 'ac223218': 765
# CSV file saved for 'ac223218'.
# Total number of images in '.git': 0
# CSV file saved for '.git'.
# Total number of images in 'ac223252': 401
# CSV file saved for 'ac223252'.
# Total number of images in 'ac223219': 995
# CSV file saved for 'ac223219'.
# Total number of images in 'ac223248': 1053
# CSV file saved for 'ac223248'.
# Total number of images in 'ac223300': 680
# CSV file saved for 'ac223300'.
# Total number of images in 'ac223306': 486
# CSV file saved for 'ac223306'.
# Total number of images in 'ac223265': 1010
# CSV file saved for 'ac223265'.
# Total number of images in 'ac223276': 554
# CSV file saved for 'ac223276'.
# Total number of images in 'ac223227': 526
# CSV file saved for 'ac223227'.
# Total number of images in 'ac223291': 611
# CSV file saved for 'ac223291'.
# Total number of images in 'ac223215': 749
# CSV file saved for 'ac223215'.
# Total number of images in 'ac223299': 845
# CSV file saved for 'ac223299'.
# Total number of images in 'ac223264': 793
# CSV file saved for 'ac223264'.
# Total number of images in 'ac223237': 1015
# CSV file saved for 'ac223237'.
# Total number of images in 'ac223225': 1026
# CSV file saved for 'ac223225'.
# Total number of images in 'ac223308': 858
# CSV file saved for 'ac223308'.
# Total number of images in 'ac223304': 806
# CSV file saved for 'ac223304'.
# Total number of images in 'ac223240': 952
# CSV file saved for 'ac223240'.
# Total number of images in 'ac223245': 690
# CSV file saved for 'ac223245'.
# Total number of images in 'ac223294': 489
# CSV file saved for 'ac223294'.
# Total number of images in 'ac223315': 700
# CSV file saved for 'ac223315'.
# Total number of images in 'ac223246': 733
# CSV file saved for 'ac223246'.
# Total number of images in 'ac223293': 522
# CSV file saved for 'ac223293'.
# Total number of images in 'ac223266': 638
# CSV file saved for 'ac223266'.
# Total number of images in 'ac223309': 953
# CSV file saved for 'ac223309'.
# Total number of images in 'ac223313': 640
# CSV file saved for 'ac223313'.
# Total number of images in 'ac223287': 757
# CSV file saved for 'ac223287'.
# Total number of images in 'ac223311': 940
# CSV file saved for 'ac223311'.
# Total number of images in 'ac223259': 1026
# CSV file saved for 'ac223259'.
# Total number of images in 'ac223221': 859
# CSV file saved for 'ac223221'.
# Total number of images in 'ac223236': 495
# CSV file saved for 'ac223236'.
# Total number of images in 'ac223298': 1372
# CSV file saved for 'ac223298'.
# Total number of images in 'ac223206': 934
# CSV file saved for 'ac223206'.
# Total number of images in 'ac223302': 1072
# CSV file saved for 'ac223302'.
# Total number of images in 'ac223268': 823
# CSV file saved for 'ac223268'.
# Total number of images in 'ac223271': 768
# CSV file saved for 'ac223271'.
# Total number of images in 'ac223281': 807
# CSV file saved for 'ac223281'.
# Total number of images in 'ac223211': 841
# CSV file saved for 'ac223211'.
# Total number of images in 'ac223231': 492
# CSV file saved for 'ac223231'.
# Total number of images in 'ac223230': 617
# CSV file saved for 'ac223230'.
# Total number of images in 'ac223249': 524
# CSV file saved for 'ac223249'.
# Total number of images in 'ac223296': 543
# CSV file saved for 'ac223296'.

# %%
# !zip -r output.zip /kaggle/working/csvfiles2/*.csv
# Out:
#   adding: kaggle/working/csvfiles2/ac223203.csv (deflated 85%)
#   adding: kaggle/working/csvfiles2/ac223204.csv (deflated 85%)
#   adding: kaggle/working/csvfiles2/ac223205.csv (deflated 85%)
#   adding: kaggle/working/csvfiles2/ac223206.csv (deflated 85%)
#   adding: kaggle/working/csvfiles2/ac223207.csv (deflated 85%)
#   adding: kaggle/working/csvfiles2/ac223208.csv (deflated 85%)
#   adding: kaggle/working/csvfiles2/ac223209.csv (deflated 85%)
#   adding: kaggle/working/csvfiles2/ac223210.csv (deflated 85%)
#   adding: kaggle/working/csvfiles2/ac223211.csv (deflated 85%)
#   adding: kaggle/working/csvfiles2/ac223212.csv (deflated 85%)
#   adding: kaggle/working/csvfiles2/ac223213.csv (deflated 85%)
#   adding: kaggle/working/csvfiles2/ac223214.csv (deflated 85%)
#   adding: kaggle/working/csvfiles2/ac223215.csv (deflated 85%)
#   adding: kaggle/working/csvfiles2/ac223216.csv (deflated 85%)
#   adding: kaggle/working/csvfiles2/ac223217.csv (deflated 85%)
#   adding: kaggle/working/csvfiles2/ac223218.csv (deflated 85%)
#   adding: kaggle/working/csvfiles2/ac223219.csv (deflated 85%)
#   adding: kaggle/working/csvfiles2/ac223220.csv (deflated 85%)
#   adding: kaggle/working/csvfiles2/ac223221.csv (deflated 85%)
#   adding: kaggle/working/csvfiles2/ac223222.csv (deflated 85%)
#   adding: kaggle/working/csvfiles2/ac223223.csv (deflated 85%)
#   adding: kaggle/working/csvfiles2/ac223224.csv (deflated 85%)
#   adding: kaggle/working/csvfiles2/ac223225.csv (deflated 85%)
#   adding: kaggle/working/csvfiles2/ac223226.csv (deflated 85%)
#   adding: kaggle/working/csvfiles2/ac223227.csv (deflated 85%)
#   adding: kaggle/working/csvfiles2/ac223228.csv (deflated 85%)
#   adding: kaggle/working/csvfiles2/ac223229.csv (deflated 85%)
#   adding: kaggle/working/csvfiles2/ac223230.csv (deflated 85%)
#   adding: kaggle/working/csvfiles2/ac223231.csv (deflated 85%)
#   adding: kaggle/working/csvfiles2/ac223232.csv (deflated 84%)
#   adding: kaggle/working/csvfiles2/ac223233.csv (deflated 85%)
#   adding: kaggle/working/csvfiles2/ac223234.csv (deflated 85%)
#   adding: kaggle/working/csvfiles2/ac223235.csv (deflated 85%)
#   adding: kaggle/working/csvfiles2/ac223236.csv (deflated 85%)
#   adding: kaggle/working/csvfiles2/ac223237.csv (deflated 85%)
#   adding: kaggle/working/csvfiles2/ac223238.csv (deflated 85%)
#   adding: kaggle/working/csvfiles2/ac223239.csv (deflated 85%)
#   adding: kaggle/working/csvfiles2/ac223240.csv (deflated 85%)
#   adding: kaggle/working/csvfiles2/ac223241.csv (deflated 85%)
#   adding: kaggle/working/csvfiles2/ac223242.csv (deflated 85%)
#   adding: kaggle/working/csvfiles2/ac223243.csv (deflated 85%)
#   adding: kaggle/working/csvfiles2/ac223244.csv (deflated 85%)
#   adding: kaggle/working/csvfiles2/ac223245.csv (deflated 85%)
#   adding: kaggle/working/csvfiles2/ac223246.csv (deflated 85%)
#   adding: kaggle/working/csvfiles2/ac223247.csv (deflated 85%)
#   adding: kaggle/working/csvfiles2/ac223248.csv (deflated 85%)
#   adding: kaggle/working/csvfiles2/ac223249.csv (deflated 85%)
#   adding: kaggle/working/csvfiles2/ac223250.csv (deflated 85%)
#   adding: kaggle/working/csvfiles2/ac223251.csv (deflated 85%)
#   adding: kaggle/working/csvfiles2/ac223252.csv (deflated 84%)
#   adding: kaggle/working/csvfiles2/ac223253.csv (deflated 84%)
#   adding: kaggle/working/csvfiles2/ac223254.csv (deflated 85%)
#   adding: kaggle/working/csvfiles2/ac223255.csv (deflated 85%)
#   adding: kaggle/working/csvfiles2/ac223256.csv (deflated 85%)
#   adding: kaggle/working/csvfiles2/ac223257.csv (deflated 85%)
#   adding: kaggle/working/csvfiles2/ac223258.csv (deflated 85%)
#   adding: kaggle/working/csvfiles2/ac223259.csv (deflated 85%)
#   adding: kaggle/working/csvfiles2/ac223260.csv (deflated 85%)
#   adding: kaggle/working/csvfiles2/ac223261.csv (deflated 85%)
#   adding: kaggle/working/csvfiles2/ac223262.csv (deflated 85%)
#   adding: kaggle/working/csvfiles2/ac223263.csv (deflated 85%)
#   adding: kaggle/working/csvfiles2/ac223264.csv (deflated 85%)
#   adding: kaggle/working/csvfiles2/ac223265.csv (deflated 85%)
#   adding: kaggle/working/csvfiles2/ac223266.csv (deflated 85%)
#   adding: kaggle/working/csvfiles2/ac223267.csv (deflated 85%)
#   adding: kaggle/working/csvfiles2/ac223268.csv (deflated 85%)
#   adding: kaggle/working/csvfiles2/ac223269.csv (deflated 85%)
#   adding: kaggle/working/csvfiles2/ac223270.csv (deflated 85%)
#   adding: kaggle/working/csvfiles2/ac223271.csv (deflated 85%)
#   adding: kaggle/working/csvfiles2/ac223272.csv (deflated 85%)
#   adding: kaggle/working/csvfiles2/ac223273.csv (deflated 85%)
#   adding: kaggle/working/csvfiles2/ac223274.csv (deflated 85%)
#   adding: kaggle/working/csvfiles2/ac223275.csv (deflated 85%)
#   adding: kaggle/working/csvfiles2/ac223276.csv (deflated 85%)
#   adding: kaggle/working/csvfiles2/ac223277.csv (deflated 85%)
#   adding: kaggle/working/csvfiles2/ac223278.csv (deflated 84%)
#   adding: kaggle/working/csvfiles2/ac223279.csv (deflated 85%)
#   adding: kaggle/working/csvfiles2/ac223280.csv (deflated 85%)
#   adding: kaggle/working/csvfiles2/ac223281.csv (deflated 85%)
#   adding: kaggle/working/csvfiles2/ac223282.csv (deflated 85%)
#   adding: kaggle/working/csvfiles2/ac223283.csv (deflated 85%)
#   adding: kaggle/working/csvfiles2/ac223284.csv (deflated 85%)
#   adding: kaggle/working/csvfiles2/ac223285.csv (deflated 85%)
#   adding: kaggle/working/csvfiles2/ac223286.csv (deflated 85%)
#   adding: kaggle/working/csvfiles2/ac223287.csv (deflated 85%)
#   adding: kaggle/working/csvfiles2/ac223288.csv (deflated 85%)
#   adding: kaggle/working/csvfiles2/ac223289.csv (deflated 85%)
#   adding: kaggle/working/csvfiles2/ac223290.csv (deflated 85%)
#   adding: kaggle/working/csvfiles2/ac223291.csv (deflated 85%)
#   adding: kaggle/working/csvfiles2/ac223292.csv (deflated 85%)
#   adding: kaggle/working/csvfiles2/ac223293.csv (deflated 84%)
#   adding: kaggle/working/csvfiles2/ac223294.csv (deflated 84%)
#   adding: kaggle/working/csvfiles2/ac223295.csv (deflated 85%)
#   adding: kaggle/working/csvfiles2/ac223296.csv (deflated 85%)
#   adding: kaggle/working/csvfiles2/ac223297.csv (deflated 85%)
#   adding: kaggle/working/csvfiles2/ac223298.csv (deflated 85%)
#   adding: kaggle/working/csvfiles2/ac223299.csv (deflated 85%)
#   adding: kaggle/working/csvfiles2/ac223300.csv (deflated 85%)
#   adding: kaggle/working/csvfiles2/ac223301.csv (deflated 85%)
#   adding: kaggle/working/csvfiles2/ac223302.csv (deflated 85%)
#   adding: kaggle/working/csvfiles2/ac223303.csv (deflated 85%)
#   adding: kaggle/working/csvfiles2/ac223304.csv (deflated 85%)
#   adding: kaggle/working/csvfiles2/ac223305.csv (deflated 85%)
#   adding: kaggle/working/csvfiles2/ac223306.csv (deflated 85%)
#   adding: kaggle/working/csvfiles2/ac223307.csv (deflated 85%)
#   adding: kaggle/working/csvfiles2/ac223308.csv (deflated 85%)
#   adding: kaggle/working/csvfiles2/ac223309.csv (deflated 85%)
#   adding: kaggle/working/csvfiles2/ac223310.csv (deflated 85%)
#   adding: kaggle/working/csvfiles2/ac223311.csv (deflated 85%)
#   adding: kaggle/working/csvfiles2/ac223312.csv (deflated 85%)
#   adding: kaggle/working/csvfiles2/ac223313.csv (deflated 85%)
#   adding: kaggle/working/csvfiles2/ac223314.csv (deflated 84%)
#   adding: kaggle/working/csvfiles2/ac223315.csv (deflated 85%)
#   adding: kaggle/working/csvfiles2/ac223316.csv (deflated 85%)
#   adding: kaggle/working/csvfiles2/ac223317.csv (deflated 85%)
#   adding: kaggle/working/csvfiles2/ac223318.csv (deflated 85%)
#   adding: kaggle/working/csvfiles2/ac223319.csv (deflated 85%)
